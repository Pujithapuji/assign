# %%
k="kite\n"
print(k)
print(k.rstrip())
# Out:
# kite
#
# kite

# %%
g="the boy is isis are tide is "
print(g.count("is"))
# Out:
# 4

# %%
import ast
c="['blue','white','black']"
print(ast.literal_eval(c))
# Out:
# ['blue', 'white', 'black']

# %%
s="adhoni fought"
h=int(input("enter the position to delete"))
f=s[:h]+s[(h+1):]
print(f)
# Out:
# enter the position to delete4
# adhoi fought

# %%
s="refrigerator"
c=0
for g in s:
  if g != "  ":
     c=c+1
print(c)
# Out:
# 12

# %%
f=input("enter string")
for h in range(len(f)):
      print(f[h])
# Out:
# enter stringtomorrow we will be
# t
# o
# m
# o
# r
# r
# o
# w
#
# w
# e
#
# w
# i
# l
# l
#
# b
# e
